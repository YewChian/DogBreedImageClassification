# %% [markdown]
# ## This model uses pre-trained weights from all layers except the first 2 Conv2D layers and the Output layer.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
#!tar -xf ./drive/MyDrive/school/PetImages.tar -C ./drive/MyDrive/school/

# %%
model = keras.models.load_model('./drive/MyDrive/school/stanford_dogs_model.keras')

# %%
model.summary()
print(len(model.layers))
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 180, 180, 3  0           []
#                                 )]
#
#  rescaling_3 (Rescaling)        (None, 180, 180, 3)  0           ['input_4[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 90, 90, 128)  3584        ['rescaling_3[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 90, 90, 128)  512        ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 90, 90, 128)  0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 90, 90, 128)  0           ['activation_24[0][0]']
#
#  separable_conv2d_21 (Separable  (None, 90, 90, 256)  34176      ['activation_25[0][0]']
#  Conv2D)
#
#  batch_normalization_25 (BatchN  (None, 90, 90, 256)  1024       ['separable_conv2d_21[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 90, 90, 256)  0           ['batch_normalization_25[0][0]']
#
#  separable_conv2d_22 (Separable  (None, 90, 90, 256)  68096      ['activation_26[0][0]']
#  Conv2D)
#
#  batch_normalization_26 (BatchN  (None, 90, 90, 256)  1024       ['separable_conv2d_22[0][0]']
#  ormalization)
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 45, 45, 256)  0          ['batch_normalization_26[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 45, 45, 256)  33024       ['activation_24[0][0]']
#
#  add_9 (Add)                    (None, 45, 45, 256)  0           ['max_pooling2d_9[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  activation_27 (Activation)     (None, 45, 45, 256)  0           ['add_9[0][0]']
#
#  separable_conv2d_23 (Separable  (None, 45, 45, 512)  133888     ['activation_27[0][0]']
#  Conv2D)
#
#  batch_normalization_27 (BatchN  (None, 45, 45, 512)  2048       ['separable_conv2d_23[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 45, 45, 512)  0           ['batch_normalization_27[0][0]']
#
#  separable_conv2d_24 (Separable  (None, 45, 45, 512)  267264     ['activation_28[0][0]']
#  Conv2D)
#
#  batch_normalization_28 (BatchN  (None, 45, 45, 512)  2048       ['separable_conv2d_24[0][0]']
#  ormalization)
#
#  max_pooling2d_10 (MaxPooling2D  (None, 23, 23, 512)  0          ['batch_normalization_28[0][0]']
#  )
#
#  conv2d_14 (Conv2D)             (None, 23, 23, 512)  131584      ['add_9[0][0]']
#
#  add_10 (Add)                   (None, 23, 23, 512)  0           ['max_pooling2d_10[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  activation_29 (Activation)     (None, 23, 23, 512)  0           ['add_10[0][0]']
#
#  separable_conv2d_25 (Separable  (None, 23, 23, 728)  378072     ['activation_29[0][0]']
#  Conv2D)
#
#  batch_normalization_29 (BatchN  (None, 23, 23, 728)  2912       ['separable_conv2d_25[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 23, 23, 728)  0           ['batch_normalization_29[0][0]']
#
#  separable_conv2d_26 (Separable  (None, 23, 23, 728)  537264     ['activation_30[0][0]']
#  Conv2D)
#
#  batch_normalization_30 (BatchN  (None, 23, 23, 728)  2912       ['separable_conv2d_26[0][0]']
#  ormalization)
#
#  max_pooling2d_11 (MaxPooling2D  (None, 12, 12, 728)  0          ['batch_normalization_30[0][0]']
#  )
#
#  conv2d_15 (Conv2D)             (None, 12, 12, 728)  373464      ['add_10[0][0]']
#
#  add_11 (Add)                   (None, 12, 12, 728)  0           ['max_pooling2d_11[0][0]',
#                                                                   'conv2d_15[0][0]']
#
#  separable_conv2d_27 (Separable  (None, 12, 12, 1024  753048     ['add_11[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_31 (BatchN  (None, 12, 12, 1024  4096       ['separable_conv2d_27[0][0]']
#  ormalization)                  )
#
#  activation_31 (Activation)     (None, 12, 12, 1024  0           ['batch_normalization_31[0][0]']
#                                 )
#
#  global_average_pooling2d_3 (Gl  (None, 1024)        0           ['activation_31[0][0]']
#  obalAveragePooling2D)
#
#  dropout_3 (Dropout)            (None, 1024)         0           ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
#  dense_3 (Dense)                (None, 120)          123000      ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 2,853,040
# Trainable params: 2,844,752
# Non-trainable params: 8,288
# __________________________________________________________________________________________________
# 38

# %%
print(model.layers[2].name)
print(model.layers[12].name)
# Out:
# conv2d_12
# conv2d_13

# %%
for count, layer in enumerate(model.layers):
  print(count, layer)
# Out:
# 0 <keras.engine.input_layer.InputLayer object at 0x7f0077cd9580>
# 1 <keras.layers.preprocessing.image_preprocessing.Rescaling object at 0x7f0077cd9640>
# 2 <keras.layers.convolutional.conv2d.Conv2D object at 0x7f00774642b0>
# 3 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f0077464430>
# 4 <keras.layers.core.activation.Activation object at 0x7f0077464ee0>
# 5 <keras.layers.core.activation.Activation object at 0x7f007743b190>
# 6 <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f0077464a30>
# 7 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f007743bbe0>
# 8 <keras.layers.core.activation.Activation object at 0x7f007743bc70>
# 9 <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f007743bd60>
# 10 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f007743ec40>
# 11 <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7f007743edc0>
# 12 <keras.layers.convolutional.conv2d.Conv2D object at 0x7f0077443580>
# 13 <keras.layers.merging.add.Add object at 0x7f0077443be0>
# 14 <keras.layers.core.activation.Activation object at 0x7f0077443dc0>
# 15 <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f0077443c40>
# 16 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f00773c6940>
# 17 <keras.layers.core.activation.Activation object at 0x7f00773c6f40>
# 18 <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f00773c6ac0>
# 19 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f00773ca9a0>
# 20 <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7f00773cab20>
# 21 <keras.layers.convolutional.conv2d.Conv2D object at 0x7f00773cd2e0>
# 22 <keras.layers.merging.add.Add object at 0x7f00773cd940>
# 23 <keras.layers.core.activation.Activation object at 0x7f00773cdb20>
# 24 <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f00773cdc10>
# 25 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f00773d16a0>
# 26 <keras.layers.core.activation.Activation object at 0x7f00773d1ca0>
# 27 <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f00773d1c40>
# 28 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f00773d4700>
# 29 <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7f00773d4880>
# 30 <keras.layers.convolutional.conv2d.Conv2D object at 0x7f00773d4fd0>
# 31 <keras.layers.merging.add.Add object at 0x7f00773d96a0>
# 32 <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f00773d9700>
# 33 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f00773de160>
# 34 <keras.layers.core.activation.Activation object at 0x7f00773de760>
# 35 <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D object at 0x7f00773de700>
# 36 <keras.layers.regularization.dropout.Dropout object at 0x7f00773dec70>
# 37 <keras.layers.core.dense.Dense object at 0x7f00773defd0>

# %%
def make_model():
    inputs = model.input

    # Entry block
    x = model.layers[1](inputs)
    x = layers.Conv2D(128, 3, strides=2, padding="same", name="conv2d_12_new")(x)
    x = model.layers[3](x)
    x = model.layers[4](x)

    previous_block_activation = x  # Set aside residual

    layer_count = 5
    for size in [256, 512, 728]:
        x = model.layers[layer_count](x)
        layer_count += 1
        x = model.layers[layer_count](x)
        layer_count += 1
        x = model.layers[layer_count](x)
        layer_count += 1

        x = model.layers[layer_count](x)
        layer_count += 1
        x = model.layers[layer_count](x)
        layer_count += 1
        x = model.layers[layer_count](x)
        layer_count += 1

        x = model.layers[layer_count](x)
        layer_count += 1

        # Project residual
        if layer_count == 12:
          residual = layers.Conv2D(size, 1, strides=2, padding="same", name="conv2d_13_new")(
              previous_block_activation
          )
          layer_count += 1
        else:
          residual = model.layers[layer_count](previous_block_activation)
          layer_count += 1

        x = layers.add([x, residual])  # Add back residual
        layer_count += 1
        previous_block_activation = x  # Set aside next residual

    x = model.layers[layer_count](x)
    layer_count += 1
    x = model.layers[layer_count](x)
    layer_count += 1
    x = model.layers[layer_count](x)
    layer_count += 1

    x = model.layers[layer_count](x)
    layer_count += 1

    x = model.layers[layer_count](x)
    layer_count += 1

    outputs = layers.Dense(1, activation="sigmoid")(x)
    return keras.Model(inputs, outputs)

image_size = (180, 180)

model2 = make_model()
keras.utils.plot_model(model2, show_shapes=True)

# %%
model2.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 180, 180, 3  0           []
#                                 )]
#
#  rescaling_3 (Rescaling)        (None, 180, 180, 3)  0           ['input_4[0][0]']
#
#  conv2d_12_new (Conv2D)         (None, 90, 90, 128)  3584        ['rescaling_3[1][0]']
#
#  batch_normalization_24 (BatchN  (None, 90, 90, 128)  512        ['conv2d_12_new[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 90, 90, 128)  0           ['batch_normalization_24[1][0]']
#
#  activation_25 (Activation)     (None, 90, 90, 128)  0           ['activation_24[1][0]']
#
#  separable_conv2d_21 (Separable  (None, 90, 90, 256)  34176      ['activation_25[1][0]']
#  Conv2D)
#
#  batch_normalization_25 (BatchN  (None, 90, 90, 256)  1024       ['separable_conv2d_21[1][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 90, 90, 256)  0           ['batch_normalization_25[1][0]']
#
#  separable_conv2d_22 (Separable  (None, 90, 90, 256)  68096      ['activation_26[1][0]']
#  Conv2D)
#
#  batch_normalization_26 (BatchN  (None, 90, 90, 256)  1024       ['separable_conv2d_22[1][0]']
#  ormalization)
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 45, 45, 256)  0          ['batch_normalization_26[1][0]']
#
#  conv2d_13_new (Conv2D)         (None, 45, 45, 256)  33024       ['activation_24[1][0]']
#
#  add (Add)                      (None, 45, 45, 256)  0           ['max_pooling2d_9[1][0]',
#                                                                   'conv2d_13_new[0][0]']
#
#  activation_27 (Activation)     (None, 45, 45, 256)  0           ['add[0][0]']
#
#  separable_conv2d_23 (Separable  (None, 45, 45, 512)  133888     ['activation_27[1][0]']
#  Conv2D)
#
#  batch_normalization_27 (BatchN  (None, 45, 45, 512)  2048       ['separable_conv2d_23[1][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 45, 45, 512)  0           ['batch_normalization_27[1][0]']
#
#  separable_conv2d_24 (Separable  (None, 45, 45, 512)  267264     ['activation_28[1][0]']
#  Conv2D)
#
#  batch_normalization_28 (BatchN  (None, 45, 45, 512)  2048       ['separable_conv2d_24[1][0]']
#  ormalization)
#
#  max_pooling2d_10 (MaxPooling2D  (None, 23, 23, 512)  0          ['batch_normalization_28[1][0]']
#  )
#
#  conv2d_14 (Conv2D)             (None, 23, 23, 512)  131584      ['add[0][0]']
#
#  add_1 (Add)                    (None, 23, 23, 512)  0           ['max_pooling2d_10[1][0]',
#                                                                   'conv2d_14[1][0]']
#
#  activation_29 (Activation)     (None, 23, 23, 512)  0           ['add_1[0][0]']
#
#  separable_conv2d_25 (Separable  (None, 23, 23, 728)  378072     ['activation_29[1][0]']
#  Conv2D)
#
#  batch_normalization_29 (BatchN  (None, 23, 23, 728)  2912       ['separable_conv2d_25[1][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 23, 23, 728)  0           ['batch_normalization_29[1][0]']
#
#  separable_conv2d_26 (Separable  (None, 23, 23, 728)  537264     ['activation_30[1][0]']
#  Conv2D)
#
#  batch_normalization_30 (BatchN  (None, 23, 23, 728)  2912       ['separable_conv2d_26[1][0]']
#  ormalization)
#
#  max_pooling2d_11 (MaxPooling2D  (None, 12, 12, 728)  0          ['batch_normalization_30[1][0]']
#  )
#
#  conv2d_15 (Conv2D)             (None, 12, 12, 728)  373464      ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 12, 12, 728)  0           ['max_pooling2d_11[1][0]',
#                                                                   'conv2d_15[1][0]']
#
#  separable_conv2d_27 (Separable  (None, 12, 12, 1024  753048     ['add_2[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_31 (BatchN  (None, 12, 12, 1024  4096       ['separable_conv2d_27[1][0]']
#  ormalization)                  )
#
#  activation_31 (Activation)     (None, 12, 12, 1024  0           ['batch_normalization_31[1][0]']
#                                 )
#
#  global_average_pooling2d_3 (Gl  (None, 1024)        0           ['activation_31[1][0]']
#  obalAveragePooling2D)
#
#  dropout_3 (Dropout)            (None, 1024)         0           ['global_average_pooling2d_3[1][0
#                                                                  ]']
#
#  dense (Dense)                  (None, 1)            1025        ['dropout_3[1][0]']
#
# ==================================================================================================
# Total params: 2,731,065
# Trainable params: 2,722,777
# Non-trainable params: 8,288
# __________________________________________________________________________________________________

# %%
import os

num_skipped = 0
for folder_name in ("Cat", "Dog"):
    folder_path = os.path.join("./drive/MyDrive/school/PetImages", folder_name)
    for fname in os.listdir(folder_path):
        fpath = os.path.join(folder_path, fname)
        try:
            fobj = open(fpath, "rb")
            is_jfif = tf.compat.as_bytes("JFIF") in fobj.peek(10)
        finally:
            fobj.close()

        if not is_jfif:
            num_skipped += 1
            # Delete corrupted image
            os.remove(fpath)

print("Deleted %d images" % num_skipped)
# Out:
# Deleted 0 images

# %%
image_size = (180, 180)
batch_size = 128

train_ds, val_ds = tf.keras.utils.image_dataset_from_directory(
    "./drive/MyDrive/school/PetImages",
    validation_split=0.2,
    subset="both",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 23410 files belonging to 2 classes.
# Using 18728 files for training.
# Using 4682 files for validation.

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
    ]
)

# %%
# Apply `data_augmentation` to the training images.
train_ds = train_ds.map(
    lambda img, label: (data_augmentation(img), label),
    num_parallel_calls=tf.data.AUTOTUNE,
)

# Prefetching samples in GPU memory helps maximize GPU utilization.
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.prefetch(tf.data.AUTOTUNE)

# %%
epochs = 25

callbacks = [
    keras.callbacks.ModelCheckpoint("save_at_{epoch}.keras"),
]
model2.compile(
    optimizer=keras.optimizers.Adam(1e-4),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
model2.fit(
    train_ds,
    epochs=epochs,
    callbacks=callbacks,
    validation_data=val_ds,
)
# Out:
# Epoch 1/25
# 147/147 [==============================] - 253s 1s/step - loss: 0.5402 - accuracy: 0.7250 - val_loss: 1.2088 - val_accuracy: 0.5248
# Epoch 2/25
# 147/147 [==============================] - 205s 1s/step - loss: 0.3515 - accuracy: 0.8481 - val_loss: 0.3107 - val_accuracy: 0.8663
# Epoch 3/25
# 147/147 [==============================] - 205s 1s/step - loss: 0.2767 - accuracy: 0.8840 - val_loss: 0.2602 - val_accuracy: 0.8883
# Epoch 4/25
# 147/147 [==============================] - 205s 1s/step - loss: 0.2315 - accuracy: 0.9044 - val_loss: 0.3686 - val_accuracy: 0.8505
# Epoch 5/25
# 147/147 [==============================] - 212s 1s/step - loss: 0.2066 - accuracy: 0.9142 - val_loss: 0.2082 - val_accuracy: 0.9152
# Epoch 6/25
# 147/147 [==============================] - 205s 1s/step - loss: 0.1863 - accuracy: 0.9235 - val_loss: 0.1916 - val_accuracy: 0.9242
# Epoch 7/25
# 147/147 [==============================] - 212s 1s/step - loss: 0.1760 - accuracy: 0.9286 - val_loss: 0.2090 - val_accuracy: 0.9184
# Epoch 8/25
# 147/147 [==============================] - 212s 1s/step - loss: 0.1614 - accuracy: 0.9349 - val_loss: 0.1795 - val_accuracy: 0.9274
# Epoch 9/25
# 147/147 [==============================] - 205s 1s/step - loss: 0.1476 - accuracy: 0.9409 - val_loss: 0.1645 - val_accuracy: 0.9357
# Epoch 10/25
# 147/147 [==============================] - 205s 1s/step - loss: 0.1398 - accuracy: 0.9435 - val_loss: 0.1527 - val_accuracy: 0.9391
# Epoch 11/25
# 147/147 [==============================] - 205s 1s/step - loss: 0.1386 - accuracy: 0.9451 - val_loss: 0.1635 - val_accuracy: 0.9344
# Epoch 12/25
# 147/147 [==============================] - 205s 1s/step - loss: 0.1257 - accuracy: 0.9496 - val_loss: 0.1619 - val_accuracy: 0.9366
# Epoch 13/25
# 147/147 [==============================] - 205s 1s/step - loss: 0.1180 - accuracy: 0.9541 - val_loss: 0.1431 - val_accuracy: 0.9396
# Epoch 14/25
# 147/147 [==============================] - 212s 1s/step - loss: 0.1137 - accuracy: 0.9538 - val_loss: 0.2806 - val_accuracy: 0.8943
# Epoch 15/25
# 147/147 [==============================] - 212s 1s/step - loss: 0.1068 - accuracy: 0.9587 - val_loss: 0.1348 - val_accuracy: 0.9475
# Epoch 16/25
# 147/147 [==============================] - 205s 1s/step - loss: 0.1012 - accuracy: 0.9603 - val_loss: 0.1700 - val_accuracy: 0.9344
# Epoch 17/25
# 147/147 [==============================] - 206s 1s/step - loss: 0.0978 - accuracy: 0.9625 - val_loss: 0.2382 - val_accuracy: 0.9184
# Epoch 18/25
# 147/147 [==============================] - 212s 1s/step - loss: 0.0964 - accuracy: 0.9626 - val_loss: 0.1205 - val_accuracy: 0.9524
# Epoch 19/25
# 147/147 [==============================] - 212s 1s/step - loss: 0.0888 - accuracy: 0.9634 - val_loss: 0.1401 - val_accuracy: 0.9438
# Epoch 20/25
# 147/147 [==============================] - 206s 1s/step - loss: 0.0848 - accuracy: 0.9673 - val_loss: 0.1473 - val_accuracy: 0.9443
# Epoch 21/25
# 147/147 [==============================] - 206s 1s/step - loss: 0.0831 - accuracy: 0.9675 - val_loss: 0.1589 - val_accuracy: 0.9408
# Epoch 22/25
# 147/147 [==============================] - 205s 1s/step - loss: 0.0804 - accuracy: 0.9675 - val_loss: 0.1262 - val_accuracy: 0.9551
# Epoch 23/25
# 147/147 [==============================] - 206s 1s/step - loss: 0.0764 - accuracy: 0.9700 - val_loss: 0.1160 - val_accuracy: 0.9566
# Epoch 24/25
# 147/147 [==============================] - 212s 1s/step - loss: 0.0726 - accuracy: 0.9719 - val_loss: 0.1147 - val_accuracy: 0.9558
# Epoch 25/25
# 147/147 [==============================] - 212s 1s/step - loss: 0.0685 - accuracy: 0.9745 - val_loss: 0.1195 - val_accuracy: 0.9545

# %%
model2.save("experiment3_model.keras")

# %%
from google.colab import files
files.download("experiment3_model.keras")
